# %% [markdown]
# # Bus
#
# This bus has a passenger entry and exit control system to monitor the number of occupants it carries and thus detect when there is too high a capacity.
#
# At each stop the entry and exit of passengers is represented by a tuple consisting of two integer numbers.
# ```
# bus_stop = (in, out)
# ```
# The succession of stops is represented by a list of these tuples.
# ```
# stops = [(in1, out1), (in2, out2), (in3, out3), (in4, out4)]
# ```
#
# ## Goals:
# * lists, tuples
# * while/for loops
# * minimum, maximum, length
# * average, standard deviation
#
# ## Tasks
# 1. Calculate the number of stops.
# 2. Assign to a variable a list whose elements are the number of passengers at each stop (in-out),
# 3. Find the maximum occupation of the bus.
# 4. Calculate the average occupation. And the standard deviation.

# %%
# variables

stops = [(10, 0), (4, 1), (3, 5), (3, 4), (5, 1), (1, 5), (5, 8), (4, 6), (2, 3)]

# %%
# 1. Calculate the number of stops.

stops = [(10, 0), (4, 1), (3, 5), (3, 4), (5, 1), (1, 5), (5, 8), (4, 6), (2, 3)]
n_stops = len(stops)
print ("The number of stops is",str(n_stops))
# Out:
# The number of stops is 9

# %% [markdown]
# **Expected output**:
# ```
# 9
# ```

# %%
# 2. Assign a variable a list whose elements are the number of passengers in each stop: 
# Each item depends on the previous item in the list + in - out.

bus_passengers = []
passengers_stop = 0

for i,j in stops:
    passengers_stop += i
    passengers_stop -= j
    bus_passengers.append(passengers_stop)

print ("There are",str(bus_passengers),"passengers in this bus.")
# Out:
# There are [10, 13, 11, 10, 14, 10, 7, 5, 4] passengers in this bus.

# %% [markdown]
# **Expected output**:
# ```
# [10, 13, 11, 10, 14, 10, 7, 5, 4]
# ```

# %%
# 3. Find the maximum occupation of the bus.
max(bus_passengers)
# Out:
# 14

# %% [markdown]
# **Expected output**:
# ```
# 14
# ```

# %%
# 4. Calculate the average occupation. And the standard deviation.

import math

mean_passengers = sum(bus_passengers)/len(bus_passengers)

print(mean_passengers)

desv = 0
desva = 0
desv_passengers = 0

for desv in bus_passengers:
    desva += (desv-mean_passengers)**2

desv_passengers = math.sqrt(desva/len(bus_passengers))

print (desv_passengers)
# Out:
# 9.333333333333334
# 3.197221015541813

# %% [markdown]
# **Expected output**:
# ```
# 9.333333333333334
# 3.197221015541813
# ```
