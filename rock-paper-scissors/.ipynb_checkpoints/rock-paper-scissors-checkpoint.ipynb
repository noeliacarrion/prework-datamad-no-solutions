# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
print ("Bienvenido al maravilloso mundo de Piedra, Papel o Tijera\n")
import random
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

lista =["Piedra", "Papel", "Tijeras"]
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

juego = 5
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
paraganar = juego - 2

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def azar():
    return random.choice(lista)
# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def pregunta():
	while True:
		huma = input("Elige: Piedra, Papel or Tijeras \n").capitalize()
		if huma == "Piedra" or huma == "Tijeras" or huma == "Papel":
			break
		else:
			print("Debes elegir una de las opciones")
			continue
	return huma


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat():
	print ("La maquina elige:",josh, "y el humano elige",hum)
	if josh == hum:
		print ("Empate")
		return (0)
	elif (josh=="Piedra" and hum=="Papel") or (josh=="Tijeras" and hum=="Piedra")or (josh=="Papel" and hum=="Tijeras"):
		print ("El humano gana")
		return (1)
	elif (josh=="Papel" and hum=="Piedra") or (josh=="Tijeras" and hum=="Papel") or (josh=="Piedra" and hum=="Tijeras"):
		print ("La maquina gana")
		return (2)
    
        
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

        
# Create two variables that accumulate the wins of each participant
ganamaquina=0
ganahumano=0
empate=0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while not (juego == 0 or ganamaquina == 3 or ganahumano == 3):
	josh = pregunta()
	hum = azar()
	combate = combat()
	if combate == 2:
		ganamaquina += 1
		juego -=1
	elif combate == 1:
		ganahumano += 1
		juego-=1
	elif combate ==0:
		empate +=1
	
	print ("La maquina lleva",ganamaquina,"puntos y el humano lleva", ganahumano,"\n")
    
# Print by console the winner of the game based on who has more accumulated wins
if ganamaquina == paraganar:
	print ("¡Joshua ha ganado!")
elif ganahumano == paraganar:
	print ("¡Humano has ganado!")
# Out:
# Bienvenido al maravilloso mundo de Piedra, Papel o Tijera
#
# Elige: Piedra, Papel or Tijeras
# papel
# La maquina elige: Papel y el humano elige Tijeras
# El humano gana
# La maquina lleva 0 puntos y el humano lleva 1
#
# Elige: Piedra, Papel or Tijeras
# papel
# La maquina elige: Papel y el humano elige Tijeras
# El humano gana
# La maquina lleva 0 puntos y el humano lleva 2
#
# Elige: Piedra, Papel or Tijeras
# papel
# La maquina elige: Papel y el humano elige Tijeras
# El humano gana
# La maquina lleva 0 puntos y el humano lleva 3
#
# ¡Humano has ganado!

# %% [markdown]
# # **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def maxpartidas():
    while True:
        try:
            sheldon = int(input("Elige un número impar de rondas para jugar "))
            if sheldon % 2 == 0:
                print("Debe ser un número impar")
                pass
            elif sheldon % 2 != 0:
                return sheldon
                break

        except ValueError:
            print("Debe ser un número impar")
            pass


# Assign a list of 5 possible options.
opciones = ["Lagarto", "Spock", "Piedra", "Papel", "Tijeras"]



# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
maximo = maxpartidas()
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
victoria = int((maximo / 2) + 1)

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def azaroso():
    return random.choice(opciones)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def eligehumana():
    while True:
        humana = input("Debes elegir: Lagarto, Spock, Piedra, Papel o Tijeras ").capitalize()
        if humana in opciones:
            return humana
            break
        else:
            print("Has introducido una opción incorrecta")
            continue

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combata():

    if hal == penny:
        print("Es un empate")
        return (0)
    elif (hal == "Piedra" and penny == "Papel") or (hal == "Tijeras" and penny == "Piedra") or (
            hal == "Papel" and penny == "Tijeras") or (hal == "Tijeras" and penny == "Spock") or (hal == "Lagarto" and penny == "Tijeras") or (hal == "Piedra" and penny == "Spock")  or (hal == "Papel" and penny == "Lagarto") or (hal == "Spock" and penny == "Lagarto") or (hal == "Spock" and penny == "Papel") or (hal == "Lagarto" and penny == "Piedra"):
        print("El humano gana")
        return (1)
    else:
        print("La maquina gana")
        return (2)
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def show():
    print("La maquina ha elegido:", hal, "y el humano ha elegido", penny)
    
# Create two variables that accumulate the wins of each participant
ganamaquina=0
ganahumano=0
empate=0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while not (maximo == 0 or ganamaquina == victoria or ganahumano == victoria):
    penny = eligehumana()
    hal = azaroso()
    combate = combata()

    if combate == 2:
        ganamaquina += 1
        maximo -=1
    elif combate == 1:
        ganahumano += 1
        maximo-=1
    elif combate ==0:
        empate +=1
    show()
    
# Print by console the winner of the game based on who has more accumulated wins
if ganamaquina == victoria:
    print ("¡Hal9000 ha ganado!")
elif ganahumano == victoria:
    print ("¡Penny has ganado!")

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
