# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options = ['piedra', 'papel', 'tijera']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
max_num_games = int(input("Máximo número de juegos: "))

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
num_games_to_win = int(max_num_games/2 + 1)
print("Necesitas {} juego/s para ganar" .format(num_games_to_win))

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def machines_choice ():
    secure_random = random.SystemRandom()
    return secure_random.choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def players_choice ():
    player = input("Elige entre 'piedra', 'papel' o 'tijera': ")
    while player not in options:
        player = input("No es correcto, vuelva a elegir entre 'piedra', 'papel' o 'tijera': ")
        if player in options:
            break
    return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def resolve_combat (maquina, jugador):
    if maquina == jugador:
        return 0
    elif maquina == 'piedra' and jugador == 'tijera':
        return 1
    elif maquina == 'papel' and jugador == 'piedra':
        return 1
    elif maquina == 'tijera' and jugador == 'papel':
        return 1
    else:
        return 2
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def state_of_the_game (maquina, jugador, resolucion, ptos_maquina, ptos_jugador):
    print("La máquina elegido: ", maquina)
    print("Tú has elegido: ", jugador)
    if resolucion == 0:
        print("Ha habido un empate")
        print("Estado del juego: Jugador {} - {} Máquina ".format(ptos_jugador, ptos_maquina))
    elif resolucion == 1:
        print("Has perdido")
        print("Estado del juego: Jugador {} - {} Máquina ".format(ptos_jugador, ptos_maquina))
    else:
        print("Has ganado")
        print("Estado del juego: Jugador {} - {} Máquina ".format(ptos_jugador, ptos_maquina))

    
# Create two variables that accumulate the wins of each participant
maquina_wins = 0
jugador_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while maquina_wins < num_games_to_win or jugador_wins < num_games_to_win:
    if maquina_wins == num_games_to_win:
        break
    elif jugador_wins == num_games_to_win:
        break
    else:
        elecc_maq = machines_choice()
        elecc_jug = players_choice()
        resultado = resolve_combat(elecc_maq, elecc_jug)
        if resultado == 1:
            maquina_wins += 1
        elif resultado == 2:
            jugador_wins += 1
        else:
            pass
        state_of_the_game(elecc_maq, elecc_jug, resultado, maquina_wins, jugador_wins)
        print("\n ---------- NUEVA MANO ---------\n")

    
# Print by console the winner of the game based on who has more accumulated wins
if maquina_wins == num_games_to_win:
    print("Ha ganado la máquina, vuelve a intentarlo")
elif jugador_wins == num_games_to_win:
    print("Has ganado a la máquina, Enhorabuena")
# Out:
# Máximo número de juegos: 3
# Necesitas 2 juego/s para ganar
# Elige entre 'piedra', 'papel' o 'tijera': papel
# La máquina elegido:  tijera
# Tú has elegido:  papel
# Has perdido
# Estado del juego: Jugador 0 - 1 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Elige entre 'piedra', 'papel' o 'tijera': papel
# La máquina elegido:  piedra
# Tú has elegido:  papel
# Has ganado
# Estado del juego: Jugador 1 - 1 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Elige entre 'piedra', 'papel' o 'tijera': papel
# La máquina elegido:  papel
# Tú has elegido:  papel
# Ha habido un empate
# Estado del juego: Jugador 1 - 1 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Elige entre 'piedra', 'papel' o 'tijera': piedra
# La máquina elegido:  papel
# Tú has elegido:  piedra
# Has perdido
# Estado del juego: Jugador 1 - 2 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Ha ganado la máquina, vuelve a intentarlo

# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def num_games ():
    games = int(input("Número de juegos (ha de ser impar): "))
    while games % 2 != 1:
        games = int(input("El número de juegos ha de ser impar, vuelva a elegir: "))
        if games % 2 == 1:
            break
    return games

# Assign a list of 5 possible options.
options = ['piedra', 'papel', 'tijera', 'lagarto', 'spok']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
max_num_games = num_games()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
num_games_to_win = int(max_num_games/2 + 1)
print("Necesitas {} juego/s para ganar" .format(num_games_to_win))

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def machines_choice ():
    secure_random = random.SystemRandom()
    return secure_random.choice(options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def players_choice ():
    player = input("Elige entre 'piedra', 'papel', 'tijera', 'lagarto' o 'spok': ")
    while player not in options:
        player = input("No es correcto, vuelva a elegir entre 'piedra', 'papel', 'tijera', 'lagarto' o 'spok': ")
        if player in options:
            break
    return player

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def resolve_combat (maquina, jugador):
    if maquina == jugador:
        return 0
    elif maquina == 'piedra' and ((jugador=='tijera') or (jugador=='lagarto')):
        return 1
    elif maquina == 'papel' and ((jugador == 'piedra') or (jugador=='spok')):
        return 1
    elif maquina == 'tijera' and ((jugador == 'papel') or (jugador=='lagarto')):
        return 1
    elif maquina == 'lagarto' and ((jugador == 'papel') or (jugador=='spok')):
        return 1
    elif maquina == 'spok' and ((jugador == 'piedra') or (jugador=='tijera')):
        return 1
    else:
        return 2

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def state_of_the_game (maquina, jugador, resolucion, ptos_maquina, ptos_jugador):
    print("La máquina elegido: ", maquina)
    print("Tú has elegido: ", jugador)
    if resolucion == 0:
        print("Ha habido un empate")
        print("Estado del juego: Jugador {} - {} Máquina ".format(ptos_jugador, ptos_maquina))
    elif resolucion == 1:
        print("Has perdido")
        print("Estado del juego: Jugador {} - {} Máquina ".format(ptos_jugador, ptos_maquina))
    else:
        print("Has ganado")
        print("Estado del juego: Jugador {} - {} Máquina ".format(ptos_jugador, ptos_maquina))

# Create two variables that accumulate the wins of each participant
maquina_wins = 0
jugador_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while maquina_wins < num_games_to_win or jugador_wins < num_games_to_win:
    if maquina_wins == num_games_to_win:
        break
    elif jugador_wins == num_games_to_win:
        break
    else:
        elecc_maq = machines_choice()
        elecc_jug = players_choice()
        resultado = resolve_combat(elecc_maq, elecc_jug)
        if resultado == 1:
            maquina_wins += 1
        elif resultado == 2:
            jugador_wins += 1
        else:
            pass
        state_of_the_game(elecc_maq, elecc_jug, resultado, maquina_wins, jugador_wins)
        print("\n ---------- NUEVA MANO ---------\n")

# Print by console the winner of the game based on who has more accumulated wins
if maquina_wins == num_games_to_win:
    print("Ha ganado la máquina, vuelve a intentarlo")
elif jugador_wins == num_games_to_win:
    print("Has ganado a la máquina, Enhorabuena")
# Out:
# Número de juegos (ha de ser impar): 4
# El número de juegos ha de ser impar, vuelva a elegir: 3
# Necesitas 2 juego/s para ganar
# Elige entre 'piedra', 'papel', 'tijera', 'lagarto' o 'spok': spok
# La máquina elegido:  spok
# Tú has elegido:  spok
# Ha habido un empate
# Estado del juego: Jugador 0 - 0 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Elige entre 'piedra', 'papel', 'tijera', 'lagarto' o 'spok': spok
# La máquina elegido:  papel
# Tú has elegido:  spok
# Has perdido
# Estado del juego: Jugador 0 - 1 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Elige entre 'piedra', 'papel', 'tijera', 'lagarto' o 'spok': spok
# La máquina elegido:  piedra
# Tú has elegido:  spok
# Has ganado
# Estado del juego: Jugador 1 - 1 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Elige entre 'piedra', 'papel', 'tijera', 'lagarto' o 'spok': lagarto
# La máquina elegido:  tijera
# Tú has elegido:  lagarto
# Has perdido
# Estado del juego: Jugador 1 - 2 Máquina
#
#  ---------- NUEVA MANO ---------
#
# Ha ganado la máquina, vuelve a intentarlo

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
