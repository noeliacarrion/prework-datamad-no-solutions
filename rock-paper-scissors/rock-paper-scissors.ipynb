# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
# Create two variables that accumulate the wins of each participant
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
# Print by console the winner of the game based on who has more accumulated wins

import random

total_games = 0
wins_player = 0
wins_computer = 0

options = ["stone", "paper", "scissors"]


def choice():
    computer_choice = random.choice(options)
    return computer_choice


def player_choice():
    player_choice = str(input("stone,paper or scissors?. Please, type your choice. "))
    if player_choice in options:
        if player_choice == "stone":
            print("You chose stone")
        elif player_choice == "paper":
            print("You chose paper")
        elif player_choice == "scissors":
            print("You chose scissors")
    else:
        while player_choice not in options:
            player_choice = input("Sorry, that's not an option.\nStone,paper or scissors? ")

    return str(player_choice)


def combat():
    result = 0
    if p_choice == "stone" and c_choice == "stone":
        print("stone vs stone\nIt's a tie!")
    elif p_choice == "paper" and c_choice == "paper":
        print("paper vs paper\nIt's a tie!")
    elif p_choice == "scissors" and c_choice == "scissors":
        print("scissors vs scissors\nIt's a tie!")
    elif p_choice == "stone" and c_choice == "paper":
        print("stone vs paper\nYou lose!")
        result = 2
    elif p_choice == "stone" and c_choice == "scissors":
        print("stone vs scissors\nYou win!")
        result = 1
    elif p_choice == "paper" and c_choice == "stone":
        print("paper vs stone\nYou win!")
        result = 1

    elif p_choice == "paper" and c_choice == "scissors":
        print("paper vs scissors\nYou lose!")
        result = 2
    elif p_choice == "scissors" and c_choice == "stone":
        print("scissors vs stone\nYou lose!")
        result = 2
    elif p_choice == "scissors" and c_choice == "paper":
        print("scissors vs paper\nYou win!")
        result = 1

    return result


while total_games < 5:
    if wins_player == 3:
        break
    elif wins_computer ==3:
        break

    c_choice = choice()
    p_choice = player_choice()
    result = combat()
    if result == 1:
        wins_player += 1
        total_games += 1
    elif result == 2:
        wins_computer += 1
        total_games += 1
    else:
        total_games += 1

    print(str(wins_player), "-", str(wins_computer), "in ", str(total_games), " games played.")


if wins_player > wins_computer:
    print("You win this game!")
elif wins_player == wins_computer:
    print ("It's a tie!")
else:
    print("You lose this game!")
# Out:
# stone,paper or scissors?. Please, type your choice. stone
# You chose stone
# stone vs paper
# You lose!
# 0 - 1 in  1  games played.
# stone,paper or scissors?. Please, type your choice. stone
# You chose stone
# stone vs stone
# It's a tie!
# 0 - 1 in  2  games played.
# stone,paper or scissors?. Please, type your choice. stone
# You chose stone
# stone vs scissors
# You win!
# 1 - 1 in  3  games played.
# stone,paper or scissors?. Please, type your choice. stone
# You chose stone
# stone vs paper
# You lose!
# 1 - 2 in  4  games played.
# stone,paper or scissors?. Please, type your choice. stone
# You chose stone
# stone vs stone
# It's a tie!
# 1 - 2 in  5  games played.
# You lose this game!

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
# Assign a list of 5 possible options.
# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
# Create two variables that accumulate the wins of each participant
# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
# Print by console the winner of the game based on who has more accumulated wins


import random

number_rounds = int(input("¿Cuántas rondas vas a jugar?, el número debe de ser impar o distinto de 0 "))
while number_rounds % 2 == 0:
    number_rounds = int(input("El número debe de ser impar"))

options = ["stone", "paper", "scissors", "lizard", "spock"]
wins_player = 0
wins_computer = 0
total_games = 0


def computer_choice():
    computer_choice = random.choice(options)
    return computer_choice

def player_choice():
    player_choice = str(input("Choose one: stone, paper, scissors, lizard or spock: "))
    while player_choice not in options:
        player_choice = str(input("Choose one: stone, paper, scissors, lizard or spock: "))
    return player_choice

def combat():

    result = 0

    if p_choice == "stone" and c_choice == "stone":
        print("stone vs stone\nIt's a tie!")
    elif p_choice == "paper" and c_choice == "paper":
        print("paper vs paper\nIt's a tie!")
    elif p_choice == "scissors" and c_choice == "scissors":
        print("scissors vs scissors\nIt's a tie!")
    elif p_choice == "lizard" and c_choice == "lizard":
        print("lizard vs lizard\nIt's a tie!")
    elif p_choice == "spock" and c_choice == "spock":
        print("spock vs spock\nIt's a tie!")


    elif p_choice == "stone" and c_choice == "paper":
        print("stone vs paper\nYou lose!")
        result = 2
    elif p_choice == "stone" and c_choice == "scissors":
        print("stone vs scissors\nYou win!")
        result = 1
    elif p_choice == "stone" and c_choice == "lizard":
        print("stone vs lizard\nYou win!")
        result = 1
    elif p_choice == "stone" and c_choice == "spock":
        print("stone vs spock\nYou lose!")
        result = 2


    elif p_choice == "paper" and c_choice == "stone":
        print("paper vs stone\nYou win!")
        result = 1
    elif p_choice == "paper" and c_choice == "scissors":
        print("paper vs scissors\nYou lose!")
        result = 2
    elif p_choice == "paper" and c_choice == "lizard":
        print("paper vs lizard\nYou lose!")
        result = 2
    elif p_choice == "paper" and c_choice == "spock":
        print("paper vs spock\nYou win!")
        result = 1


    elif p_choice == "scissors" and c_choice == "stone":
        print("scissors vs stone\nYou lose!")
        result = 2
    elif p_choice == "scissors" and c_choice == "paper":
        print("scissors vs paper\nYou win!")
        result = 1
    elif p_choice == "scissors" and c_choice == "lizard":
        print("scissors vs lizard\nYou win!")
        result = 1
    elif p_choice == "scissors" and c_choice == "spock":
        print("scissors vs spock\nYou lose!")
        result = 2

    elif p_choice == "lizard" and c_choice == "stone":
        print("lizard vs stone\nYou lose!")
        result = 2
    elif p_choice == "lizard" and c_choice == "paper":
        print("lizard vs paper\nYou win!")
        result = 1
    elif p_choice == "lizard" and c_choice == "scissors":
        print("lizard vs scissors\nYou lose!")
        result = 2
    elif p_choice == "lizard" and c_choice == "spock":
        print("lizard vs spock\nYou win!")
        result = 1

    elif p_choice == "spock" and c_choice == "stone":
        print("spock vs stone\nYou win!")
        result = 1
    elif p_choice == "spock" and c_choice == "paper":
        print("spock vs paper\nYou lose!")
        result = 2
    elif p_choice == "spock" and c_choice == "scissors":
        print("spock vs scissors\nYou win!")
        result = 1
    elif p_choice == "spock" and c_choice == "spock":
        print("spock vs lizard\nYou lose!")
        result = 2

    return result


while total_games < number_rounds:

    if wins_player > number_rounds // 2:
        break
    elif wins_computer > number_rounds // 2:
        break

    c_choice = str(computer_choice())
    p_choice = str(player_choice())
    result = combat()
# no consigo convertilo a función y que devuelva los valores correctamente
    if result == 1:
        wins_player += 1
        total_games += 1
    elif result == 2:
        wins_computer += 1
        total_games += 1
    else:
        total_games += 1
    print(str(wins_player), "-", str(wins_computer), "in ", str(total_games), " games played.")

if wins_player > wins_computer:
    print("You win this game!")
elif wins_player == wins_computer:
    print("It's a tie!")
else:
    print("You lose this game!")
# Out:
# ¿Cuántas rondas vas a jugar?, el número debe de ser impar o distinto de 0 5
# Choose one: stone, paper, scissors, lizard or spock: paper
# paper vs stone
# You win!
# 1 - 0 in  1  games played.
# Choose one: stone, paper, scissors, lizard or spock: paper
# paper vs lizard
# You lose!
# 1 - 1 in  2  games played.
# Choose one: stone, paper, scissors, lizard or spock: paper
# paper vs spock
# You win!
# 2 - 1 in  3  games played.
# Choose one: stone, paper, scissors, lizard or spock: paper
# paper vs lizard
# You lose!
# 2 - 2 in  4  games played.
# Choose one: stone, paper, scissors, lizard or spock: paper
# paper vs stone
# You win!
# 3 - 2 in  5  games played.
# You win this game!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
