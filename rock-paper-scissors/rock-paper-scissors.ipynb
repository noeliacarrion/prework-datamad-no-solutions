# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

from random import choice

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

options = ['stone', 'paper', 'scissors']


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

total_games = 5


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

win_games = (total_games)//2 + 1

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def machine_option():
    
    return choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def human_option():
    
    option = input('You have to choose between stone, paper and scissors \n')
    
    assert option.lower() in options, "You must choose between stone, paper and scissors"
    return option


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat(machine, human):
    if machine == human:
        return 0
    elif machine == 'stone':
        if human == 'paper':
            return 2
        elif human == 'scissors':
            return 1
    elif machine == 'paper':
        if human == 'stone':
            return 1
        elif human == 'scissors':
            return 2
    elif machine == 'scissors':
        if human == 'stone':
            return 2
        elif human == 'paper':
            return 1
 
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game():
    
    m = machine_option()
    
    h = human_option()
    
    print("The choice of the machine is: ",m)
    
    print("Your choice is: ",h)
    
    c = combat(m,h)
    
    print("The result of the combat is ",c)
    
    return c
    
    
    
    
    
# Create two variables that accumulate the wins of each participant

machine_wins = 0

human_wins = 0


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while machine_wins < win_games and human_wins < win_games:
    g = game()
    if g == 1:
        machine_wins += 1
    elif g == 2:
        human_wins += 1
    
# Print by console the winner of the game based on who has more accumulated wins
if machine_wins > human_wins:
    print("Machine wins!")
elif machine_wins < human_wins:
    print("You win!")
# Out:
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  paper
# Your choice is:  stone
# The result of the combat is  1
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  stone
# Your choice is:  stone
# The result of the combat is  0
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  stone
# Your choice is:  stone
# The result of the combat is  0
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  stone
# Your choice is:  stone
# The result of the combat is  0
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  stone
# Your choice is:  stone
# The result of the combat is  0
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  scissors
# Your choice is:  stone
# The result of the combat is  2
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  paper
# Your choice is:  stone
# The result of the combat is  1
# You have to choose between stone, paper and scissors
# stone
# The choice of the machine is:  paper
# Your choice is:  stone
# The result of the combat is  1
# Machine wins

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

from random import choice

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

options = ['stone', 'paper', 'scissors', 'lizard', 'spock']


# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

total_games = 5


# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

win_games = (total_games)//2 + 1

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def machine_option():
    
    return choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def human_option():
    
    option = input('You have to choose between stone, paper, scissors, lizard or spock \n')
    
    assert option.lower() in options, "You must choose between stone, paper, scissors, lizard or spock"
    return option


# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat(machine, human):
    if machine == human:
        return 0
    elif machine == 'stone':
        if human == 'paper':
            return 2
        elif human == 'scissors':
            return 1
        elif human == 'lizard':
            return 1
        elif human == 'spock':            
            return 2
    elif machine == 'paper':
        if human == 'stone':
            return 1
        elif human == 'scissors':
            return 2
        elif human == 'lizard':
            return 2
        elif human == 'spock':
            return 1
    elif machine == 'scissors':
        if human == 'stone':
            return 2
        elif human == 'paper':
            return 1
        elif human == 'lizard':
            return 1
        elif human == 'spock':
            return 2
    elif machine == 'lizard':
        if human == 'stone':
            return 2
        elif human == 'paper':
            return 1
        elif human == 'scissors':
            return 2
        elif human == 'spock':
            return 1
    elif machine == 'spock':
        if human == 'stone':
            return 1
        elif human == 'paper':
            return 2
        elif human == 'lizard':
            return 2
        elif human == 'scissors':
            return 1
 
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game():
    
    m = machine_option()
    
    h = human_option()
    
    print("The choice of the machine is: ",m)
    
    print("Your choice is: ",h)
    
    c = combat(m,h)
    
    print("The result of the combat is ",c)
    
    return c
    
    
    
    
    
# Create two variables that accumulate the wins of each participant

machine_wins = 0

human_wins = 0


# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while machine_wins < win_games and human_wins < win_games:
    g = game()
    if g == 1:
        machine_wins += 1
    elif g == 2:
        human_wins += 1
    
# Print by console the winner of the game based on who has more accumulated wins
if machine_wins > human_wins:
    print("Machine wins!")
elif machine_wins < human_wins:
    print("You win!")
# Out:
# You have to choose between stone, paper, scissors, lizard or spock
# spock
# The choice of the machine is:  lizard
# Your choice is:  spock
# The result of the combat is  1
# You have to choose between stone, paper, scissors, lizard or spock
# stone
# The choice of the machine is:  stone
# Your choice is:  stone
# The result of the combat is  0
# You have to choose between stone, paper, scissors, lizard or spock
# stone
# The choice of the machine is:  paper
# Your choice is:  stone
# The result of the combat is  1
# You have to choose between stone, paper, scissors, lizard or spock
# stone
# The choice of the machine is:  stone
# Your choice is:  stone
# The result of the combat is  0
# You have to choose between stone, paper, scissors, lizard or spock
# stone
# The choice of the machine is:  spock
# Your choice is:  stone
# The result of the combat is  1
# Machine wins!

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
