# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list
import random 

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.
options = ['rock', 'paper', 'scissors']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
games = 3

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
to_win = games - 1

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.
def computer():
    options = ['rock', 'paper', 'scissors']
    return random.choice(options)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.
def player():
    while True:
        option = input("Paper, rock, scissors? ------> ")
        opcion = option.lower().strip()
        if opcion in ["paper", "rock", "scissors"]:
            return opcion

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
def combat_result(computer_choice, player_choice):
    if computer_choice == player_choice:
        return 0
    elif computer_choice == 'rock' and player_choice == 'paper':
        return 2
    elif computer_choice == 'scissors' and player_choice == 'rock':
        return 2
    elif computer_choice == 'paper' and player_choice == 'scissors':
        return 2
    else:
        return 1
    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def result(combat_result, computer_choice, player_choice):
    result = ''
    if combat_result == 1:
        result = 'Computer wins!'
    elif combat_result == 2:
        result = 'Player wins!'
    elif combat_result == 0:
        result = 'It\'s a tie!'
    
    return ('Computer chooses {} - Player chooses {} -----> {}'.format(computer_choice, player_choice, result) )
    
# Create two variables that accumulate the wins of each participant
computer_wins = 0
player_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.

while computer_wins < to_win and player_wins < to_win:
    computer_choice = computer()
    player_choice = player()
    combat = combat_result(computer_choice, player_choice)
    
    print(result(combat, computer_choice, player_choice))
    
    if combat == 1:
        computer_wins += 1
        print('Computer: {} Player: {}'.format(computer_wins, player_wins))
    elif combat == 2:
        player_wins += 1
        print('Computer: {} Player: {}'.format(computer_wins, player_wins))
    else:
        print('Computer: {} Player: {}'.format(computer_wins, player_wins))
        
    
else:
    if computer_wins > player_wins:
        print('\n'
              '________________\n'
              '\n'
              'COMPUTER WINS!!!!'
              '\n'
              '________________\n')
    elif computer_wins < player_wins:
        print('\n'
              '________________\n'
              '\n'
              'PLAYER WINS!!!!'
              '\n'
              '________________\n')
    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Paper, rock, scissors? ------> rock
# Computer chooses scissors - Player chooses rock -----> Player wins!
# Computer: 0 Player: 1
# Paper, rock, scissors? ------> paper
# Computer chooses paper - Player chooses paper -----> It's a tie!
# Computer: 0 Player: 1
# Paper, rock, scissors? ------> scissors
# Computer chooses paper - Player chooses scissors -----> Player wins!
# Computer: 0 Player: 2
#
# ________________
#
# PLAYER WINS!!!!
# ________________

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module
import random 

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking
def odd_number():
#     print('Please type an odd number')
    while True:
        number = input('Please type an odd number ----> ')
        try:
            number = int(number)
            if number % 2 != 0:
                return number
        except ValueError:
            print('THAT WAS NOT NUMBER!')

# Assign a list of 5 possible options.
options = ['rock', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used
games = odd_number()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games
to_win = games - 1

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.
def computer():
    options = ['rock', 'paper', 'scissors', 'lizard', 'spock']
    return random.choice(options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.
def player():
    while True:
        option = input("Paper, rock, scissors, lizard, spock? ------> ")
        opcion = option.lower().strip()
        if opcion in ['rock', 'paper', 'scissors', 'lizard', 'spock']:
            return opcion

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options
def combat_result(computer_choice, player_choice):
    if computer_choice == player_choice:
        return 0
    elif computer_choice == 'rock' and player_choice == 'paper':
        return 2
    elif computer_choice == 'scissors' and player_choice == 'rock':
        return 2
    elif computer_choice == 'paper' and player_choice == 'scissors':
        return 2
    elif computer_choice == 'paper' and player_choice == 'lizard':
        return 2
    elif computer_choice == 'spock' and player_choice == 'lizard':
        return 2
    elif computer_choice == 'scissors' and player_choice == 'spock':
        return 2
    elif computer_choice == 'rock' and player_choice == 'spock':
        return 2
    elif computer_choice == 'lizard' and player_choice == 'scissors':
        return 2
    elif computer_choice == 'lizard' and player_choice == 'rock':
        return 2
    else:
        return 1

    
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated
def result(combat_result, computer_choice, player_choice):
    result = ''
    if combat_result == 1:
        result = 'Computer wins!'
    elif combat_result == 2:
        result = 'Player wins!'
    elif combat_result == 0:
        result = 'It\'s a tie!'
    
    return ('Computer chooses {} - Player chooses {} -----> {}'.format(computer_choice, player_choice, result) )
    
# Create two variables that accumulate the wins of each participant
computer_wins = 0
player_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while computer_wins < to_win and player_wins < to_win:
    computer_choice = computer()
    player_choice = player()
    combat = combat_result(computer_choice, player_choice)
    
    print(result(combat, computer_choice, player_choice))
    
    if combat == 1:
        computer_wins += 1
        print('Computer: {} Player: {}'.format(computer_wins, player_wins))
    elif combat == 2:
        player_wins += 1
        print('Computer: {} Player: {}'.format(computer_wins, player_wins))
    else:
        print('Computer: {} Player: {}'.format(computer_wins, player_wins))
        
    
else:
    if computer_wins > player_wins:
        print('\n'
              '________________\n'
              '\n'
              'COMPUTER WINS!!!!'
              '\n'
              '________________\n')
    elif computer_wins < player_wins:
        print('\n'
              '________________\n'
              '\n'
              'PLAYER WINS!!!!'
              '\n'
              '________________\n')
        
    
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Please type an odd number ----> 5
# Paper, rock, scissors, lizard, spock? ------> spock
# Computer chooses lizard - Player chooses spock -----> Computer wins!
# Computer: 1 Player: 0
# Paper, rock, scissors, lizard, spock? ------> lizard
# Computer chooses rock - Player chooses lizard -----> Computer wins!
# Computer: 2 Player: 0
# Paper, rock, scissors, lizard, spock? ------> rock
# Computer chooses scissors - Player chooses rock -----> Player wins!
# Computer: 2 Player: 1
# Paper, rock, scissors, lizard, spock? ------> rock
# Computer chooses scissors - Player chooses rock -----> Player wins!
# Computer: 2 Player: 2
# Paper, rock, scissors, lizard, spock? ------> paper
# Computer chooses spock - Player chooses paper -----> Computer wins!
# Computer: 3 Player: 2
# Paper, rock, scissors, lizard, spock? ------> paper
# Computer chooses lizard - Player chooses paper -----> Computer wins!
# Computer: 4 Player: 2
#
# ________________
#
# COMPUTER WINS!!!!
# ________________

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
