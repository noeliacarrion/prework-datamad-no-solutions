# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

plays = ["rock", "paper", "scissors"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

max_games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

min_victories = int(round((max_games / 2),0))

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def computer_play(plays): 
    return random.choice(plays)

# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def player_play(plays, help_text="Choose your movement (Remember that has to be Rock, Paper or Scissors):"):
    while True:
        player_play = input(help_text).lower()
        if player_play not in plays:
            print("Wrong movement. Please enter Rock, Paper or Scissors.")
            continue
        else:
            break
    return player_play

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat(computer, player):
    if computer == player:
        return 0
    elif (computer == "rock") & (player == "scissors"):
        return 1
    elif (computer == "paper") & (player == "rock"):
        return 1
    elif (computer == "scissors") & (player == "paper"):
        return 1
    elif (player == "rock") & (computer == "scissors"):
        return 2
    elif (player == "paper") & (computer == "rock"):
        return 2
    elif (player == "scissors") & (computer == "paper"):
        return 2
    

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def show_moves(computer, player):
    print("Computer plays: {}, Player does: {}".format(computer, player))
    

def game_status(combat):
    if combat == 1:
        print(f"{play_1} vs {play_2} Player 2 wins")
    elif combat == 2:
        print(f"{play_1} vs {play_2} Player 1 wins")
    else:
        print("It's a tie!")
    
# Create two variables that accumulate the wins of each participant

computer_wins = 0
player_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
while True:
    play_1 = player_play(plays)
    play_2 = computer_play(plays)
    result = combat(play_1, play_2)
    #game_status = game_status(combat)
    print(f'Computer plays {play_2}')
    if result == 2:
        player_wins += 1
        print(f"{play_1} vs {play_2}: Player 2 wins")
    elif result == 1:
        computer_wins += 1
        print(f"{play_1} vs {play_2}: Player 1 wins")
    else:
        print("It's a tie!")
    print(f'{computer_wins} - {player_wins}')
    if (computer_wins < min_victories) & (player_wins < min_victories):
        continue
    else:
        print(f'Game Finished. Computer: {computer_wins}, Player: {player_wins}')
        break
# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Choose your movement (Remember that has to be Rock, Paper or Scissors):rock
# Computer plays scissors
# rock vs scissors: Player 1 wins
# 1 - 0
# Choose your movement (Remember that has to be Rock, Paper or Scissors):scissors
# Computer plays rock
# scissors vs rock: Player 2 wins
# 1 - 1
# Choose your movement (Remember that has to be Rock, Paper or Scissors):paper
# Computer plays scissors
# paper vs scissors: Player 2 wins
# 1 - 2
# Game Finished. Computer: 1, Player: 2

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random
import math

# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def number_of_games():
    while True:
        number_of_games = int(input("Enter the number of games (must be an odd number):"))
        if number_of_games %2 == 0:
            print("Wrong number. The number of games must be odd")
            continue
        else:
            break
    return number_of_games

# Assign a list of 5 possible options.

options = ["rock", "paper", "scissors", "lizard", "spock"]

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used

maximum_games = number_of_games()

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

games_to_win = int(math.ceil(maximum_games / 2))
print("Games to Win {}".format(games_to_win))

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def computer_move(options):
    return random.choice(options)

computer = computer_move(options)

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def player_move(options, help_text="Choose your movement (Remember that has to be Rock, Paper, Scissors, Lizard or Spock):"):
    while True:
        player_move = input(help_text).lower()
        if player_move not in options:
            print("Wrong movement. Please enter Rock, Paper or Scissors.")
            continue
        else:
            break
    return player_move

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options

def combat(play_1, play_2):
    rock = {'rock': 0,'paper': 1, 'scissors': 2, 'lizard': 2, 'spock': 1}
    paper = {'rock': 2, 'paper':0, 'scissors': 1, 'lizard': 1, 'spock': 2}
    scissors = {'rock': 1, 'paper': 2, 'scissors': 0, 'lizard': 2, 'spock': 1} 
    lizard = {'rock': 1, 'paper': 2, 'scissors': 1, 'lizard':0, 'spock': 2}
    spock = {'rock': 2, 'paper': 1, 'scissors': 2, 'lizard': 1, 'spock':0}
    plays_dict = {'rock': rock, 'paper': paper, 'scissors': scissors, 'lizard': lizard, 'spock': spock}
    play_1 = plays_dict[play_1]
    return play_1[play_2]

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def game_status(player_move, computer_move, result):
    if result == 1:
        print(f"{computer_move} vs {player_move}: Player wins")
    elif result == 2:
        print(f"{computer_move} vs {player_move}: Computer wins")
    else:
        print("It's a tie!")
                
# Create two variables that accumulate the wins of each participant

computer_wins = 0
player_wins = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.


while True:
    player = player_move(options)
    computer = computer_move(options)
    combat = combat(player,computer)
    status = game_status(player, computer, combat)
    if combat == 2:
        player_wins += 1
    elif combat== 1:
        computer_wins += 1
    print(player_wins + computer_wins)
    if (computer_wins < games_to_win) & (player_wins < games_to_win):
        pass
    else:
        print(f'Game Finished. Computer: {computer_wins}, Player: {player_wins}')
        break

# Print by console the winner of the game based on who has more accumulated wins
# Out:
# Enter the number of games (must be an odd number):7
# Games to Win 4
# Choose your movement (Remember that has to be Rock, Paper, Scissors, Lizard or Spock):rock
# scissors vs rock: Computer wins
# 1
# Choose your movement (Remember that has to be Rock, Paper, Scissors, Lizard or Spock):asdf
# Wrong movement. Please enter Rock, Paper or Scissors.
# Choose your movement (Remember that has to be Rock, Paper, Scissors, Lizard or Spock):paper
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-34861882c8bd> in <module>
#      93     player = player_move(options)
#      94     computer = computer_move(options)
# ---> 95     combat = combat(player,computer)
#      96     status = game_status(player, computer, combat)
#      97     if combat == 2:
#
# TypeError: 'int' object is not callable

# %% [markdown]
# **Expected output**: Depends on the inputs, you know how to play and what to expect.
